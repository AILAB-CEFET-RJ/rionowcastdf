# %% [markdown]
# # CorrDiff - Fase 16 v2
#
# Baselines clássicos, métricas congeladas e handoff NVIDIA.

# %%
from pathlib import Path
import pandas as pd
OUT = Path('../analysis_outputs/16_baselines')

# %% [markdown]
# ## Métricas pontuais

# %%
point = pd.read_parquet(OUT/'point_metrics.parquet')
display(point.sort_values(['split','cohort','domain','baseline']))

# %% [markdown]
# ## Skill por threshold

# %%
thr = pd.read_parquet(OUT/'threshold_metrics.parquet')
display(thr.sort_values(['split','cohort','threshold_dbz','baseline']))

# %% [markdown]
# ## FSS

# %%
fss = pd.read_parquet(OUT/'fss_metrics.parquet')
display(fss.sort_values(['split','cohort','threshold_dbz','nominal_support_km','baseline']))

# %% [markdown]
# ## Máximo por patch

# %%
patch = pd.read_parquet(OUT/'patch_max_metrics.parquet')
display(patch.sort_values(['split','cohort','condition','baseline']))

# %% [markdown]
# ## Nota
#
# Nenhum modelo neural é treinado nesta fase. O handoff para NVIDIA é gerado em `nvidia_handoff/`.
