# %% [markdown]
# # CorrDiff — Fase 17
#
# Desenho formal das ablações de condicionamento no ambiente NVIDIA CorrDiff.

# %%
from pathlib import Path
import pandas as pd
OUT = Path('../analysis_outputs/17_conditioning_ablations')
matrix = pd.read_csv(OUT/'ablation_matrix.csv')
display(matrix)

# %% [markdown]
# ## Necessidade: leave-one-family-out

# %%
display(matrix[matrix.experiment_id.isin(['C00','C04','C05','C06'])])

# %% [markdown]
# ## Suficiência: single-family

# %%
display(matrix[matrix.experiment_id.isin(['C00','C01','C02','C03'])])

# %% [markdown]
# ## Representação derivada

# %%
display(matrix[matrix.experiment_id.isin(['C00','C07','C08','C09','C10'])])

# %% [markdown]
# ## Runs planejados

# %%
r = pd.read_csv(OUT/'planned_runs_stage_R.csv')
d = pd.read_csv(OUT/'planned_runs_stage_D_mandatory.csv')
print('Stage R:', len(r), 'runs')
print('Stage D mandatory:', len(d), 'runs')
display(r.head())
display(d.head())

# %% [markdown]
# ## Regra
#
# 2023 e 2024 permanecem bloqueados. A Fase 17 apenas congela o desenho; a Fase 18 fará o mapeamento para as classes/configs reais do NVIDIA CorrDiff.
